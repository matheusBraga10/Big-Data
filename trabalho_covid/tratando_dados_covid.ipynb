# %% [markdown]
# **Importando as variáveis de ambiente**

# %%
import pandas as pd

# %% [markdown]
# **Montando o drive virtual**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Carregando os dados**

# %%
path_matheus = '/content/drive/MyDrive/ANÁLISE E DESENVOLVIMENTO DE SISTEMAS/4⁰ Período /Bid-Data/Trabalho DATA-TOWN/trabalho_final/database/arquivo_tratado/arquivo_concatenado_covid.csv'
arquivo_tratado_covid = pd.read_csv(path_matheus)

# %% [markdown]
# **Visualisando os dados do arquivo**

# %%
arquivo_tratado_covid
# Out:
#                regiao estado  municipio  coduf    codmun  codRegiaoSaude  \
# 0              Brasil    NaN        NaN     76       NaN             NaN
# 1              Brasil    NaN        NaN     76       NaN             NaN
# 2              Brasil    NaN        NaN     76       NaN             NaN
# 3              Brasil    NaN        NaN     76       NaN             NaN
# 4              Brasil    NaN        NaN     76       NaN             NaN
# ...               ...    ...        ...    ...       ...             ...
# 7204421  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204422  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204423  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204424  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204425  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %% [markdown]
# **Descartando os valores duplicados**

# %%
lista_colunas = ['regiao',	'estado',	'municipio',	'coduf',	'codmun',	'codRegiaoSaude',	'nomeRegiaoSaude',	'data',	'semanaEpi',	'populacaoTCU2019',	'casosAcumulado',	'casosNovos',	'obitosAcumulado',	'obitosNovos',	'Recuperadosnovos',	'emAcompanhamentoNovos',	'interior/metropolitana']
arquivo_tratado_covid.drop_duplicates(lista_colunas, inplace = True)

# %% [markdown]
# **Visualisando o arquivo após a exclusão dos valores duplicados**

# %%
arquivo_tratado_covid

# %% [markdown]
# ****

# %% [markdown]
# **Tratando valores nulos**

# %%
arquivo_tratado_covid['interior/metropolitana'] = arquivo_tratado_covid['interior/metropolitana'].fillna(0)
arquivo_tratado_covid['emAcompanhamentoNovos'] = arquivo_tratado_covid['emAcompanhamentoNovos'].fillna(0)
arquivo_tratado_covid['Recuperadosnovos'] = arquivo_tratado_covid['Recuperadosnovos'].fillna(0)
arquivo_tratado_covid['obitosNovos'] = arquivo_tratado_covid['obitosNovos'].fillna(0)
arquivo_tratado_covid['casosNovos'] = arquivo_tratado_covid['casosNovos'].fillna(0)

arquivo_tratado_covid
# Out:
#                regiao estado  municipio  coduf    codmun  codRegiaoSaude  \
# 0              Brasil    NaN        NaN     76       NaN             NaN
# 1              Brasil    NaN        NaN     76       NaN             NaN
# 2              Brasil    NaN        NaN     76       NaN             NaN
# 3              Brasil    NaN        NaN     76       NaN             NaN
# 4              Brasil    NaN        NaN     76       NaN             NaN
# ...               ...    ...        ...    ...       ...             ...
# 7204421  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204422  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204423  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204424  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204425  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %% [markdown]
# **Salvado dados tratados**

# %%
path_matheus_tratamento_dados = '/content/drive/MyDrive/ANÁLISE E DESENVOLVIMENTO DE SISTEMAS/4⁰ Período /Bid-Data/Trabalho DATA-TOWN/trabalho_final/database/dados_tratados/dados_tratados.csv'
arquivo_tratado_covid.to_csv(path_matheus_tratamento_dados, index=False)

# %%
arquivo_tratado_covid = pd.read_csv(path_matheus_tratamento_dados)
arquivo_tratado_covid
# Out:
#                regiao estado  municipio  coduf    codmun  codRegiaoSaude  \
# 0              Brasil    NaN        NaN     76       NaN             NaN
# 1              Brasil    NaN        NaN     76       NaN             NaN
# 2              Brasil    NaN        NaN     76       NaN             NaN
# 3              Brasil    NaN        NaN     76       NaN             NaN
# 4              Brasil    NaN        NaN     76       NaN             NaN
# ...               ...    ...        ...    ...       ...             ...
# 7204421  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204422  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204423  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204424  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204425  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...
