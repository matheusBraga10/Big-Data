# %% [markdown]
# **Importando bibliotecas**

# %%
import pandas as pd

# %% [markdown]
# **Montando o drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Carregando dados**

# %%
path_matheus_tratamento_dados = '/content/drive/MyDrive/ANÁLISE E DESENVOLVIMENTO DE SISTEMAS/4⁰ Período /Bid-Data/Trabalho DATA-TOWN/trabalho_final/database/arquivo_tratado/arquivo_concatenado_covid.csv'
arquivo_tratado_covid = pd.read_csv(path_matheus_tratamento_dados)

# %% [markdown]
# - Visualização topo

# %%
arquivo_tratado_covid.head()
# Out:
#    regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 0  2020-02-25          9       210147125.0             0.0           0
# 1  2020-02-26          9       210147125.0             1.0           1
# 2  2020-02-27          9       210147125.0             1.0           0
# 3  2020-02-28          9       210147125.0             1.0           0
# 4  2020-02-29          9       210147125.0             2.0           1
#
#    obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# ...

# %% [markdown]
# - Visualização fim

# %%
arquivo_tratado_covid.tail()
# Out:
#                regiao estado  municipio  coduf    codmun  codRegiaoSaude  \
# 7204421  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204422  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204423  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204424  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204425  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 7204421  DISTRITO FEDERAL  2023-09-25         39         3015268.0
# 7204422  DISTRITO FEDERAL  2023-09-26         39         3015268.0
# 7204423  DISTRITO FEDERAL  2023-09-27         39         3015268.0
# 7204424  DISTRITO FEDERAL  2023-09-28         39         3015268.0
# 7204425  DISTRITO FEDERAL  2023-09-29         39         3015268.0
#
#          casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# ...

# %% [markdown]
# **Analise exploratória da Database**

# %% [markdown]
# - Imprimindo o numero de linhas e colunas

# %%
arquivo_tratado_covid.shape
# Out:
# (7204426, 17)

# %% [markdown]
# - Visualizar o arquivo que importamos e o seu tamanho

# %%
display(arquivo_tratado_covid)
# Out:
#                regiao estado  municipio  coduf    codmun  codRegiaoSaude  \
# 0              Brasil    NaN        NaN     76       NaN             NaN
# 1              Brasil    NaN        NaN     76       NaN             NaN
# 2              Brasil    NaN        NaN     76       NaN             NaN
# 3              Brasil    NaN        NaN     76       NaN             NaN
# 4              Brasil    NaN        NaN     76       NaN             NaN
# ...               ...    ...        ...    ...       ...             ...
# 7204421  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204422  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204423  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204424  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
# 7204425  Centro-Oeste     DF  BrasÃ­lia     53  530010.0         53001.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %% [markdown]
# - Descobrindo o período da análise

# %%
inicio = pd.to_datetime(arquivo_tratado_covid['data']).dt.date.min()
fim = pd.to_datetime(arquivo_tratado_covid['data']).dt.date.max()
print(inicio)
print(fim)
# Out:
# 2020-02-25
# 2023-09-29

# %% [markdown]
# - Verifica valores nulos e tipos de dados

# %%
arquivo_tratado_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7204426 entries, 0 to 7204425
# Data columns (total 17 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   regiao                  object
#  1   estado                  object
#  2   municipio               object
#  3   coduf                   int64
#  4   codmun                  float64
#  5   codRegiaoSaude          float64
#  6   nomeRegiaoSaude         object
#  7   data                    object
#  8   semanaEpi               int64
#  9   populacaoTCU2019        float64
#  10  casosAcumulado          float64
#  11  casosNovos              int64
#  12  obitosAcumulado         int64
#  13  obitosNovos             int64
#  14  Recuperadosnovos        float64
#  15  emAcompanhamentoNovos   float64
#  16  interior/metropolitana  float64
# dtypes: float64(7), int64(5), object(5)
# memory usage: 934.4+ MB

# %% [markdown]
# - Imprimindo o tipo dos dados por coluna

# %%
arquivo_tratado_covid.dtypes
# Out:
# regiao                     object
# estado                     object
# municipio                  object
# coduf                       int64
# codmun                    float64
# codRegiaoSaude            float64
# nomeRegiaoSaude            object
# data                       object
# semanaEpi                   int64
# populacaoTCU2019          float64
# casosAcumulado            float64
# casosNovos                  int64
# obitosAcumulado             int64
# obitosNovos                 int64
# Recuperadosnovos          float64
# emAcompanhamentoNovos     float64
# interior/metropolitana    float64
# dtype: object

# %% [markdown]
# - Imprimindo os numeros de dados nulos por coluna

# %%
print(arquivo_tratado_covid.isnull().sum())
# Out:
# regiao                          0
# estado                       1313
# municipio                   63686
# coduf                           0
# codmun                      36764
# codRegiaoSaude              63686
# nomeRegiaoSaude             63686
# data                            0
# semanaEpi                       0
# populacaoTCU2019            26922
# casosAcumulado                  0
# casosNovos                      0
# obitosAcumulado                 0
# obitosNovos                     0
# Recuperadosnovos          7203114
# emAcompanhamentoNovos     7203114
# interior/metropolitana      63686
# dtype: int64

# %% [markdown]
# - Entendendo melhor os valores nulos

# %%
arquivo_tratado_covid['populacaoTCU2019'].value_counts()
# Out:
# 5237.0     6410
# 7642.0     5128
# 3203.0     5128
# 4573.0     5128
# 11019.0    5128
#            ...
# 5714.0     1282
# 13865.0    1282
# 31603.0    1282
# 20598.0    1282
# 5821.0     1282
# Name: populacaoTCU2019, Length: 5104, dtype: int64

# %% [markdown]
# - Analisando informações estatisticas

# %%
arquivo_tratado_covid.describe()
# Out:
#               coduf        codmun  codRegiaoSaude     semanaEpi  \
# count  7.204426e+06  7.167662e+06    7.140740e+06  7.204426e+06
# mean   3.236019e+01  3.252580e+05    3.240312e+04  2.661200e+01
# std    9.874140e+00  9.853503e+04    9.836342e+03  1.427729e+01
# min    1.100000e+01  1.100000e+05    1.100100e+04  1.000000e+00
# 25%    2.500000e+01  2.512000e+05    2.501000e+04  1.500000e+01
# 50%    3.100000e+01  3.146100e+05    3.105900e+04  2.700000e+01
# 75%    4.100000e+01  4.119150e+05    4.101500e+04  3.800000e+01
# max    7.600000e+01  5.300100e+05    5.300100e+04  5.300000e+01
#
#        populacaoTCU2019  casosAcumulado    casosNovos  obitosAcumulado  \
# count      7.177504e+06    7.204426e+06  7.204426e+06     7.204426e+06
# mean       1.144207e+05    1.201236e+04  1.573906e+01     2.629465e+02
# std        2.970190e+06    3.613487e+05  7.248789e+02     7.736386e+03
# min        7.810000e+02    0.000000e+00 -3.368370e+05     0.000000e+00
# ...

# %% [markdown]
# - Entendendo melhor as informações estatisticas

# %%
arquivo_tratado_covid.plot(kind='box', figsize=(50,10), subplots=True)
# Out:
# coduf                        Axes(0.125,0.11;0.0545775x0.77)
# codmun                    Axes(0.190493,0.11;0.0545775x0.77)
# codRegiaoSaude            Axes(0.255986,0.11;0.0545775x0.77)
# semanaEpi                 Axes(0.321479,0.11;0.0545775x0.77)
# populacaoTCU2019          Axes(0.386972,0.11;0.0545775x0.77)
# casosAcumulado            Axes(0.452465,0.11;0.0545775x0.77)
# casosNovos                Axes(0.517958,0.11;0.0545775x0.77)
# obitosAcumulado           Axes(0.583451,0.11;0.0545775x0.77)
# obitosNovos               Axes(0.648944,0.11;0.0545775x0.77)
# Recuperadosnovos          Axes(0.714437,0.11;0.0545775x0.77)
# emAcompanhamentoNovos      Axes(0.77993,0.11;0.0545775x0.77)
# interior/metropolitana    Axes(0.845423,0.11;0.0545775x0.77)
# dtype: object

# %% [markdown]
# - O que seriam outliers?

# %%
arquivo_tratado_covid[arquivo_tratado_covid['casosNovos'] > 100000]
# Out:
#            regiao estado                 municipio  coduf    codmun  \
# 1574271    Brasil    NaN                       NaN     76       NaN
# 1574361    Brasil    NaN                       NaN     76       NaN
# 2591249    Brasil    NaN                       NaN     76       NaN
# 2591306    Brasil    NaN                       NaN     76       NaN
# 2594802   Sudeste     RJ                       NaN     33       NaN
# 3625136    Brasil    NaN                       NaN     76       NaN
# 3625140    Brasil    NaN                       NaN     76       NaN
# 3625141    Brasil    NaN                       NaN     76       NaN
# 3625142    Brasil    NaN                       NaN     76       NaN
# 3625143    Brasil    NaN                       NaN     76       NaN
# 3625144    Brasil    NaN                       NaN     76       NaN
# 3625145    Brasil    NaN                       NaN     76       NaN
# 3625147    Brasil    NaN                       NaN     76       NaN
# ...

# %% [markdown]
# - Entendendo melhor essas informações

# %%
arquivo_tratado_covid.municipio.value_counts()
# Out:
# Bom Jesus                  6410
# SÃ£o Domingos              6410
# Bonito                     5128
# Santa Helena               5128
# Santa Terezinha            5128
#                            ...
# ConceiÃ§Ã£o do JacuÃ­pe    1282
# ConceiÃ§Ã£o do CoitÃ©      1282
# ConceiÃ§Ã£o do Almeida     1282
# ConceiÃ§Ã£o da Feira       1282
# BrasÃ­lia                  1282
# Name: municipio, Length: 5297, dtype: int64

# %%
arquivo_tratado_covid.municipio.value_counts().plot(kind='bar')
# Out:
# <Axes: >
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 129 (\x81) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 141 (\x8d) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 147 (\x93) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 130 (\x82) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 137 (\x89) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# - Verificando os valores unicos

# %%
arquivo_tratado_covid.nunique()
# Out:
# regiao                         6
# estado                        27
# municipio                   5297
# coduf                         28
# codmun                      5591
# codRegiaoSaude               450
# nomeRegiaoSaude              440
# data                        1313
# semanaEpi                     53
# populacaoTCU2019            5104
# casosAcumulado            107358
# casosNovos                  7786
# obitosAcumulado            20565
# obitosNovos                 1201
# Recuperadosnovos            1248
# emAcompanhamentoNovos       1279
# interior/metropolitana         2
# dtype: int64

# %%
arquivo_tratado_covid.duplicated().value_counts()
# Out:
# False    7204426
# dtype: int64

# %% [markdown]
# - Gráficos para variáveis numericas

# %%
arquivo_tratado_covid = arquivo_tratado_covid.copy()

continuous = []
categorical = []

for c in arquivo_tratado_covid.columns[:-1]:
  if arquivo_tratado_covid.nunique()[c] >= 5297:
    continuous.append(c)
  else:
    categorical.append(c)

# %%
continuous
# Out:
# ['municipio', 'codmun', 'casosAcumulado', 'casosNovos', 'obitosAcumulado']

# %%
arquivo_tratado_covid[continuous].head()
# Out:
#   municipio  codmun  casosAcumulado  casosNovos  obitosAcumulado
# 0       NaN     NaN             0.0           0                0
# 1       NaN     NaN             1.0           1                0
# 2       NaN     NaN             1.0           0                0
# 3       NaN     NaN             1.0           0                0
# 4       NaN     NaN             2.0           1                0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (10, 10))

colunas = [	'regiao',	'estado',	'municipio',	'coduf'	,'codmun',	'codRegiaoSaude',	'nomeRegiaoSaude',	'data'	,'semanaEpi',	'populacaoTCU2019'	,'casosAcumulado',	'casosNovos'	,'obitosAcumulado'	,'obitosNovos'	,'Recuperadosnovos',	'emAcompanhamentoNovos',	'interior/metropolitana']

sns.heatmap(arquivo_tratado_covid[colunas].corr(), vmax= 1., square = True)

plt.show()
# Out:
# <ipython-input-23-72feb5a81869>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(arquivo_tratado_covid[colunas].corr(), vmax= 1., square = True)

# %% [markdown]
# - https://www.youtube.com/watch?v=2Rux12aGD6o&t=0s

# %% [markdown]
# - Pergunras para o professor
#   - Temos aproximadamente 64milregistros nulos da covid, em 7,2 mi. Tratamos ou escluimos?
