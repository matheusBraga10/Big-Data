# %% [markdown]
# #Extraindo Arquivos

# %% [markdown]
# - Instalando bibliotecas

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.1.2/spark-3.1.2-bin-hadoop2.7.tgz
# !tar xf spark-3.1.2-bin-hadoop2.7.tgz
# !pip install pyspark
# !pip install -q findspark

#----------------------------------------------------------------------------------------

# %% [markdown]
# - Importando bibliotecas

# %%
import os

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"

os.environ["SPARK_HOME"] = "/content/spark-3.1.2-bin-hadoop2.7"

# %%
import findspark

findspark.init()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.master('local[*]').appName("Iniciando com Spark").config('spark.ui.port', '4050').getOrCreate()

# %% [markdown]
# - Extraindo e salvando arquivos

# %%
import zipfile

zipfile.ZipFile('/content/drive/MyDrive/ANÁLISE E DESENVOLVIMENTO DE SISTEMAS/4⁰ Período /Bid-Data/Trabalho DATA-TOWN/trabalho_final/database/HIST_PAINEL_COVIDBR_29set2023.zip','r').extractall('/content/drive/MyDrive/ANÁLISE E DESENVOLVIMENTO DE SISTEMAS/4⁰ Período /Bid-Data/Trabalho DATA-TOWN/trabalho_final/sugestao_novo_tema/HIST_PAINEL_COVIDBR_29set2023')

# %% [markdown]
# - Carregando arquivos

# %%
path = "/content/drive/MyDrive/ANÁLISE E DESENVOLVIMENTO DE SISTEMAS/4⁰ Período /Bid-Data/Trabalho DATA-TOWN/trabalho_final/database/HIST_PAINEL_COVIDBR_29set2023"
dados_covid = spark.read.csv(path, sep=";", inferSchema=True);

# %% [markdown]
# - Lendo e compreendendo dados

# %%
dados_covid.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#  |-- _c7: string (nullable = true)
#  |-- _c8: string (nullable = true)
#  |-- _c9: string (nullable = true)
#  |-- _c10: string (nullable = true)
#  |-- _c11: string (nullable = true)
#  |-- _c12: string (nullable = true)
#  |-- _c13: string (nullable = true)
#  |-- _c14: string (nullable = true)
#  |-- _c15: string (nullable = true)
#  |-- _c16: string (nullable = true)

# %%
dados_covid.count()
# Out:
# 7204434

# %%
dados_covid.limit(3).toPandas()
# Out:
#       _c0     _c1        _c2    _c3     _c4             _c5              _c6  \
# 0  regiao  estado  municipio  coduf  codmun  codRegiaoSaude  nomeRegiaoSaude
# 1  Brasil    None       None     76    None            None             None
# 2  Brasil    None       None     76    None            None             None
#
#           _c7        _c8               _c9            _c10        _c11  \
# 0        data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos
# 1  2022-07-01         26         210147125        32434063       76045
# 2  2022-07-02         26         210147125        32471847       37784
#
#               _c12         _c13              _c14                   _c15  \
# 0  obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos
# 1           671700          284          30873682                 888681
# 2           671858          158          30880584                 919405
#
#                      _c16
# 0  interior/metropolitana
# ...
